# %% [markdown]
# <a href="https://colab.research.google.com/github/yugendharpusala/TNS.IN.TRAINING/blob/main/Module_1_Mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

filename = list(uploaded.keys())[0]

df = pd.read_csv(filename, encoding="latin1")

print("File uploaded successfully")
print(df.head())
# Out:
#      <input type="file" id="files-b9c91a1b-77e6-4d9a-a619-9bbffbc4c0e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9c91a1b-77e6-4d9a-a619-9bbffbc4c0e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
top = df.nlargest(10, "subscribers")[["Youtuber", "subscribers"]]
x = top["Youtuber"]
y = top["subscribers"]
print("X values:", list(x))
print("Y values:", list(y))

plt.bar(x, y)
plt.xticks(rotation=90)
plt.title("Top 10 Channels by Subscribers")
plt.show()
# Out:
# X values: ['T-Series', 'YouTube Movies', 'MrBeast', 'Cocomelon - Nursery Rhymes', 'SET India', 'Music', 'ýýý Kids Diana Show', 'PewDiePie', 'Like Nastya', 'Vlad and Niki']
# Y values: [245000000, 170000000, 166000000, 162000000, 159000000, 119000000, 112000000, 111000000, 106000000, 98900000]

# %%
top = df.nlargest(10, "video views")[["Youtuber", "video views"]]
x = top["Youtuber"]
y = top["video views"]
print("X values:", list(x))
print("Y values:", list(y))

plt.bar(x, y)
plt.xticks(rotation=90)
plt.title("Top 10 Channels by Video Views")
plt.show()
# Out:
# X values: ['T-Series', 'Cocomelon - Nursery Rhymes', 'SET India', 'Sony SAB', 'ýýý Kids Diana Show', 'Like Nastya', 'WWE', 'Vlad and Niki', 'Zee TV', 'Colors TV']
# Y values: [228000000000.0, 164000000000.0, 148000000000.0, 101000000000.0, 93247040539.0, 90479060027.0, 77428473662.0, 77180169894.0, 73139054467.0, 61510906457.0]

# %%
country = df["Country"].value_counts().head(10)
x = country.index
y = country.values
print("X values:", list(x))
print("Y values:", list(y))

plt.bar(x, y)
plt.xticks(rotation=45)
plt.title("Top Countries by Number of Creators")
plt.show()
# Out:
# X values: ['United States', 'India', 'Brazil', 'United Kingdom', 'Mexico', 'Indonesia', 'Spain', 'Thailand', 'South Korea', 'Russia']
# Y values: [np.int64(313), np.int64(168), np.int64(62), np.int64(43), np.int64(33), np.int64(28), np.int64(22), np.int64(18), np.int64(17), np.int64(16)]
